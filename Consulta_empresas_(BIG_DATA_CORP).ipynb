# %%
pip install fpdf2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 3.4 MB/s eta 0:00:00a 0:00:010m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 4.6 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# instalação de biblioteca

#pip install fpdf2

# %%
# 📦 #### Imports
##import os
##import yaml
import json
import datetime
##import requests
import re
from getpass import getpass
# from fpdf import FPDF, XPos, YPos


import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from google.colab import auth
from google.colab import data_table
from google.cloud import bigquery


# ⚙️ #### Setup
data_table.enable_dataframe_formatter()
data_table.DataTable.max_rows = 1000000
data_table.DataTable.max_columns = 300

auth.authenticate_user()
bq_client = bigquery.Client(project='ai-services-sae')

# 🔐 #### Credenciais
bigdata_token_id = '68375c090347ebbb5f2a6797'
bigdata_token_hash = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..UZERauMBKE62U2sr7vWzBbRD0j79Eid0DKHSQkByf9I'

# 🧠 #### Função para buscar dados
def fetch_bdc_data(
    document_number: str,
    url: str,
    dataset: str,
    token_hash: str,
    token_id: str
):
    headers = {
        "Accept": "application/json",
        "Content-Type": "application/json",
        "AccessToken": token_hash,
        "TokenId": token_id
    }
    payload = {
        "q": f"doc{{{document_number}}}",
        "Datasets": dataset
    }

    response = requests.post(url, json=payload, headers=headers)
    response.raise_for_status()
    return response.json()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 12
#       8 from getpass import getpass
#       9 # from fpdf import FPDF, XPos, YPos
# ---> 12 import matplotlib.pyplot as plt
#      13 import pandas as pd
#      14 import numpy as np
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# 🎯 #### Input do CPF (Document Number)
cpf_input = input("Digite o CPF (com ou sem pontos e traços): ")

# 🔢 #### Sanitizando o CPF
cpf_sanitizado = re.sub(r'\D', '', cpf_input)  # Remove qualquer coisa que não seja número

print(f'CPF utilizado na busca: {cpf_sanitizado}')

# 🚀 #### Buscar dados
bdc_data = fetch_bdc_data(
    document_number=cpf_sanitizado,
    url="https://plataforma.bigdatacorp.com.br/empresas",
    dataset="""basic_data
               """,
    token_hash=bigdata_token_hash,
    token_id=bigdata_token_id
)

# 📜 #### Resultado
print(json.dumps(bdc_data, indent=4, ensure_ascii=False))



resultado = json.dumps(bdc_data, indent=4, ensure_ascii=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-a89cdeb0e410> in <cell line: 0>()
#       1 # 🎯 #### Input do CPF (Document Number)
# ----> 2 cpf_input = input("Digite o CPF (com ou sem pontos e traços): ")
#       3
#       4 # 🔢 #### Sanitizando o CPF
#       5 cpf_sanitizado = re.sub(r'\D', '', cpf_input)  # Remove qualquer coisa que não seja número
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...

# %% [markdown]
# # **Consulta de Dados em Massa**

# %%
import re
import json
import requests

# 🔐 Credenciais
bigdata_token_id = '68375c090347ebbb5f2a6797'
bigdata_token_hash = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..UZERauMBKE62U2sr7vWzBbRD0j79Eid0DKHSQkByf9I'

# 🧠 Função de consulta à API
def fetch_bdc_data(document_number, url, dataset, token_hash, token_id):
    headers = {
        "Accept": "application/json",
        "Content-Type": "application/json",
        "AccessToken": token_hash,
        "TokenId": token_id
    }
    payload = {
        "q": f"doc{{{document_number}}}",
        "Datasets": dataset
    }
    response = requests.post(url, json=payload, headers=headers)
    response.raise_for_status()
    return response.json()




# ✅ Lista de CNPJs para consulta
cnpjs = [

"43728245000142"
]




# 🔢 Sanitização dos CNPJs (caso venham formatados)
cnpjs_sanitizados = [re.sub(r'\D', '', cnpj) for cnpj in cnpjs]

# 🚀 Consulta em massa
resultados = []
for cnpj in cnpjs_sanitizados:
    print(f"🔍 Buscando dados para: {cnpj}")
    try:
        bdc_data = fetch_bdc_data(
            document_number=cnpj,
            url="https://plataforma.bigdatacorp.com.br/empresas",
            dataset="""basic_data,
               processes.filter(partypolarity = PASSIVE),
               kyc.filter(standardized_type, standardized_sanction_type, type, sanctions_source = Conselho Nacional de Justiça)""",
            token_hash=bigdata_token_hash,
            token_id=bigdata_token_id
        )
        resultados.append(bdc_data)
    except Exception as e:
        print(f"⚠️ Erro ao buscar dados para {cnpj}: {str(e)}")
        resultados.append({
            "document_number": cnpj,
            "error": str(e)
        })

# 📜 Resultado final em JSON
resultado_json = json.dumps(resultados, indent=4, ensure_ascii=False)
print("\n📦 Resultado da consulta em massa:")
print(resultado_json)
# Out:
# 🔍 Buscando dados para: 57839076000122
# 🔍 Buscando dados para: 57745437000171
#
# 📦 Resultado da consulta em massa:
# [
#     {
#         "Result": [
#             {
#                 "MatchKeys": "doc{57839076000122}",
#                 "BasicData": {
#                     "TaxIdNumber": "57839076000122",
#                     "TaxIdCountry": "Brazil",
#                     "AlternativeIdNumbers": {},
#                     "OfficialName": "APOSTARAIZ LTDA",
#                     "TradeName": "APOSTARAIZ",
#                     "Aliases": {
#                         "UnstandardizedRFOfficialName": "APOSTARAIZ LTDA",
#                         "UnstandardizedRFTradeName": "APOSTARAIZ"
#                     },
#                     "NameUniquenessScore": 1,
#                     "OfficialNameUniquenessScore": 1,
#                     "TradeNameUniquenessScore": 1,
#                     "FoundedDate": "2024-10-25T00:00:00Z",
#                     "Age": 0,
# ...

# %%
# Instalar dependência para salvar como Excel
# !pip install openpyxl

import pandas as pd

# Processar os dados da variável `resultados`
records = []

for item in resultados:
    # Verifica se houve erro na consulta
    if "Result" not in item or not item["Result"]:
        continue

    for result in item["Result"]:
        bd = result.get("BasicData", {})
        main_activity = ""
        if "Activities" in bd:
            main = next((a for a in bd["Activities"] if a.get("IsMain")), {})
            main_activity = main.get("Activity", "")

        records.append({
            "CNPJ": bd.get("TaxIdNumber"),
            "Razão Social": bd.get("OfficialName"),
            "Nome Fantasia": bd.get("TradeName", ""),
            "UF": bd.get("HeadquarterState"),
            "Situação": bd.get("TaxIdStatus"),
            "Regime Tributário": bd.get("TaxRegime"),
            "Capital (R$)": float(bd.get("AdditionalOutputData", {}).get("CapitalRS", 0.0)),
            "Data de Fundação": bd.get("FoundedDate", "")[:10],
            "Atividade Principal": main_activity
        })

# Criar DataFrame
df = pd.DataFrame(records)

# Exibir preview
df.head()

# Salvar como Excel (.xlsx)
excel_filename = "resultado_cnpjs.xlsx"
df.to_excel(excel_filename, index=False)

# Oferecer download no Colab
from google.colab import files
files.download(excel_filename)
